# %%
example = {"key1":"value1","key2":"value2","key3":"value3"}

# %%
example["key1"]
# Out:
# 'value1'

# %%
example.key1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 example.key1
#
# AttributeError: 'dict' object has no attribute 'key1'

# %%
from box import ConfigBox

# %%
example = ConfigBox({"key1":"value1","key2":"value2","key3":"value3"})
example.key1
# Out:
# 'value1'

# %%
#Ensure annotations 
from ensure import ensure_annotations

@ensure_annotations
def get_products(x:int,y:int) -> int:
    return x * y

# %%
get_products(3,4)
# Out:
# 12

# %%
get_products(4,7.8)
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 get_products(4,7.8)
#
# File c:\project\DataScienceProject-\venv0\lib\site-packages\ensure\main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'float'> to <function get_products at 0x000002572E1CC0D0> does not match annotation type <class 'int'>
